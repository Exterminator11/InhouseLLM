# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random
regenerate=True

## Input data directory
data_dir = "test"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
loader = PyPDFLoader("http://localhost:8501/_stcore/upload_file/c603c78c-60f7-4d9b-bb6c-80fec4f9974d/83948113-ac35-43fa-8963-05a4c347d6ac")
# loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 5>()
#       1 ## Dir PDF Loader
#       2 # loader = PyPDFDirectoryLoader(inputdirectory)
#       3 ## File Loader
#       4 # loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
# ----> 5 loader = PyPDFLoader("http://localhost:8501/_stcore/upload_file/c603c78c-60f7-4d9b-bb6c-80fec4f9974d/83948113-ac35-43fa-8963-05a4c347d6ac")
#       6 # loader = DirectoryLoader(inputdirectory, show_progress=True)
#       7 documents = loader.load()
#
# File c:\Users\Mohammad Arshad Ali\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_community\document_loaders\pdf.py:157, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images)
#     153 except ImportError:
#     154     raise ImportError(
#     155         "pypdf package not found, please install it with " "`pip install pypdf`"
#     156     )
# --> 157 super().__init__(file_path, headers=headers)
#     158 self.parser = PyPDFParser(password=password, extract_images=extract_images)
#
# File c:\Users\Mohammad Arshad Ali\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_community\document_loaders\pdf.py:91, in BasePDFLoader.__init__(self, file_path, headers)
#      89 r = requests.get(self.file_path, headers=self.headers)
#      90 if r.status_code != 200:
# ---> 91     raise ValueError(
#      92         "Check the url of your file; returned status code %s"
#      93         % r.status_code
#      94     )
#      96 with open(temp_pdf, mode="wb") as f:
#      97     f.write(r.content)
#
# ValueError: Check the url of your file; returned status code 405

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (2, 3)
#                                                 text  \
# 0  ABSTRACT\n\nZero-day network interruption assa...
# 1  of mounting cyber attacks. With a large portio...
#
#                          source                          chunk_id
# 0  data_input\test\zero_day.txt  d2c2552381744b1ea4bb62edbaa5dad9
# 1  data_input\test\zero_day.txt  bdc68d203d3e4f73994b13d6d0221cd5

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
# regenerate = False

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# [
#    {
#        "node_1": "Zero-day network interruption attacks",
#        "node_2": "Cyber attacks",
#        "edge": "Cyber attacks, also known as zero-day attacks, comprise a regular online security threat that exploit the weaknesses of an organization's infrastructure. These types of attacks have been contributing significantly to data breaches resulting in losses of money, time, and resources."
#    },
#    {
#        "node_1": "Zero-day network interruption attacks",
#        "node_2": "Data leaks",
#        "edge": "Zero-day attacks are a major contributor to data leaks that have led to losses of money, time, and resources."
#    },
#    {
#        "node_1": "Zero-day network interruption attacks",
#        "node_2": "Prevention",
#        "edge": "Our solution to detect and prevent such attacks is a desktop application that monitors your network traffic in real time and looks for any anomalies or malicious activity that may be happening and works to minimize the damage caused by prevention."
#    },
#    {
#        "node_1": "Zero-day network interruption attacks",
#        "node_2": "Machine Learning",
#        "edge": "Keywords: Zero day attacks, Attack detection, Machine Learning."
#    },
#    {
#        "node_1": "Protection",
#        "node_2": "Malicious connections",
#        "edge": "Our software utilizes a network flow collection tool called CIC Flowmeter to collect network flows from the user in real time. These flows are analyzed using a two layer approach. Protection is employed by blocking network port access for specific IP Addresses that have been flagged as malicious."
#    },
#    {
#        "node_1": "Cyber attacks",
#        "node_2": "Digital infrastructure",
#        "edge": "With a large portion of our public and private data being hosted on digital infrastructure, growing with the advantages of seamless connectivity is the threat of mounting cyber attacks."
#    }
# ][
#   {
#     "node_1": "zero-day attack",
#     "node_2": "unknown vulnerabilities",
#     "edge": "occurs when criminals exploit unknown vulnerabilities in hardware or software, unbeknownst to manufacturers."
#   },
#   {
#     "node_1": "zero-day attack",
#     "node_2": "no defenses or safeguards",
#     "edge": "leaves developers with little time to identify and mitigate the damage, as they catch organizations off guard."
#   },
#   {
#     "node_1": "zero-day attack",
#     "node_2": "irreparable damage",
#     "edge": "if undetected, this attack may inflict irreparable damage to essential system architecture."
#   },
#   {
#     "node_1": "cyber attacks",
#     "node_2": "vulnerabilities in hardware and software",
#     "edge": "protecting computer systems and networks from malicious attacks has become a critical concern in the current digital era, as cybercriminals, leveraging the power of the internet, are constantly searching for vulnerabilities in hardware and software that can be exploited to steal or corrupt data."
#   },
#   {
#     "node_1": "cyber security landscape",
#     "node_2": "complexity and scale of cyber attacks",
#     "edge": "within the rapidly expanding cyber security landscape, the complexity and scale of cyber attacks has grown exponentially."
#   }
# ](11, 5)
#                                   node_1                 node_2  \
# 0  zero-day network interruption attacks          cyber attacks
# 1  zero-day network interruption attacks             data leaks
# 2  zero-day network interruption attacks             prevention
# 3  zero-day network interruption attacks       machine learning
# 4                             protection  malicious connections
#
#                                                 edge  \
# 0  Cyber attacks, also known as zero-day attacks,...
# 1  Zero-day attacks are a major contributor to da...
# 2  Our solution to detect and prevent such attack...
# 3  Keywords: Zero day attacks, Attack detection, ...
# 4  Our software utilizes a network flow collectio...
#
#                            chunk_id  count
# 0  d2c2552381744b1ea4bb62edbaa5dad9      4
# 1  d2c2552381744b1ea4bb62edbaa5dad9      4
# 2  d2c2552381744b1ea4bb62edbaa5dad9      4
# 3  d2c2552381744b1ea4bb62edbaa5dad9      4
# 4  d2c2552381744b1ea4bb62edbaa5dad9      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                                     node_1                  node_2  \
# 107  zero-day network interruption attacks  digital infrastructure
# 108  zero-day network interruption attacks        machine learning
# 109  zero-day network interruption attacks   malicious connections
# 110  zero-day network interruption attacks              prevention
# 111  zero-day network interruption attacks              protection
#
#                                               chunk_id  count  \
# 107  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...      4
# 108  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...      4
# 109  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...      4
# 110  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...      4
# 111  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...      4
#
#                      edge
# 107  contextual proximity
# 108  contextual proximity
# 109  contextual proximity
# 110  contextual proximity
# 111  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                       node_1  \
# 0      complexity and scale of cyber attacks
# 1                              cyber attacks
# 2                              cyber attacks
# 3                              cyber attacks
# 4                              cyber attacks
# 5                              cyber attacks
# 6                              cyber attacks
# 7                              cyber attacks
# 8                              cyber attacks
# 9                              cyber attacks
# 10                  cyber security landscape
# 11                  cyber security landscape
# 12                                data leaks
# 13                                data leaks
# 14                    digital infrastructure
# 15                    digital infrastructure
# 16                        irreparable damage
# 17                          machine learning
# 18                          machine learning
# 19                     malicious connections
# 20                     malicious connections
# 21                 no defenses or safeguards
# 22                                prevention
# 23                                prevention
# 24                                protection
# 25                                protection
# 26                                protection
# 27                   unknown vulnerabilities
# 28  vulnerabilities in hardware and software
# 29                           zero-day attack
# 30                           zero-day attack
# 31                           zero-day attack
# 32                           zero-day attack
# 33                           zero-day attack
# 34                           zero-day attack
# 35                           zero-day attack
# 36     zero-day network interruption attacks
# 37     zero-day network interruption attacks
# 38     zero-day network interruption attacks
# 39     zero-day network interruption attacks
# 40     zero-day network interruption attacks
# 41     zero-day network interruption attacks
# 42     zero-day network interruption attacks
#
#                                       node_2  \
# 0                            zero-day attack
# 1                                 data leaks
# 2                     digital infrastructure
# 3                           machine learning
# 4                      malicious connections
# 5                                 prevention
# 6                                 protection
# 7   vulnerabilities in hardware and software
# 8                            zero-day attack
# 9      zero-day network interruption attacks
# 10     complexity and scale of cyber attacks
# 11                           zero-day attack
# 12                             cyber attacks
# 13     zero-day network interruption attacks
# 14                             cyber attacks
# 15     zero-day network interruption attacks
# 16                           zero-day attack
# 17                             cyber attacks
# 18     zero-day network interruption attacks
# 19                             cyber attacks
# 20     zero-day network interruption attacks
# 21                           zero-day attack
# 22                             cyber attacks
# 23     zero-day network interruption attacks
# 24                             cyber attacks
# 25                     malicious connections
# 26     zero-day network interruption attacks
# 27                           zero-day attack
# 28                           zero-day attack
# 29     complexity and scale of cyber attacks
# 30                             cyber attacks
# 31                  cyber security landscape
# 32                        irreparable damage
# 33                 no defenses or safeguards
# 34                   unknown vulnerabilities
# 35  vulnerabilities in hardware and software
# 36                             cyber attacks
# 37                                data leaks
# 38                    digital infrastructure
# 39                          machine learning
# 40                     malicious connections
# 41                                prevention
# 42                                protection
#
#                                              chunk_id  \
# 0   bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 1   d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 2   d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 3   d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 4   d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 5   d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 6   d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 7                    bdc68d203d3e4f73994b13d6d0221cd5
# 8   bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 9   d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 10                   bdc68d203d3e4f73994b13d6d0221cd5
# 11  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 12  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 13  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 14  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 15  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 16  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 17  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 18  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 19  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 20  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 21  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 22  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 23  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 24  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 25                   d2c2552381744b1ea4bb62edbaa5dad9
# 26  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 27  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 28  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 29  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 30  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 31  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 32  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 33  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 34  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 35  bdc68d203d3e4f73994b13d6d0221cd5,bdc68d203d3e4...
# 36  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 37  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 38  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 39  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 40  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 41  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
# 42  d2c2552381744b1ea4bb62edbaa5dad9,d2c2552381744...
#
#                                                  edge  count
# 0                                contextual proximity      3
# 1                                contextual proximity      2
# 2   With a large portion of our public and private...      6
# 3                                contextual proximity      2
# 4                                contextual proximity      2
# 5                                contextual proximity      2
# 6                                contextual proximity      2
# 7   protecting computer systems and networks from ...      4
# 8                                contextual proximity      3
# 9                                contextual proximity      8
# 10  within the rapidly expanding cyber security la...      4
# 11                               contextual proximity      3
# 12                               contextual proximity      2
# 13                               contextual proximity      4
# 14                               contextual proximity      2
# 15                               contextual proximity      4
# 16                               contextual proximity      3
# 17                               contextual proximity      2
# 18                               contextual proximity      4
# 19                               contextual proximity      2
# 20                               contextual proximity      4
# 21                               contextual proximity      3
# 22                               contextual proximity      2
# 23                               contextual proximity      4
# 24                               contextual proximity      2
# 25  Our software utilizes a network flow collectio...      4
# 26                               contextual proximity      4
# 27                               contextual proximity      3
# 28                               contextual proximity      3
# 29                               contextual proximity      3
# 30                               contextual proximity      3
# 31                               contextual proximity      3
# 32  if undetected, this attack may inflict irrepar...      7
# 33  leaves developers with little time to identify...      7
# 34  occurs when criminals exploit unknown vulnerab...      7
# 35                               contextual proximity      3
# 36  Cyber attacks, also known as zero-day attacks,...     12
# 37  Zero-day attacks are a major contributor to da...      8
# 38                               contextual proximity      4
# 39  Keywords: Zero day attacks, Attack detection, ...      8
# 40                               contextual proximity      4
# 41  Our solution to detect and prevent such attack...      8
# 42                               contextual proximity      4

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (15,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  3
# [['complexity and scale of cyber attacks', 'cyber security landscape', 'no defenses or safeguards', 'unknown vulnerabilities', 'vulnerabilities in hardware and software', 'zero-day attack'], ['cyber attacks', 'data leaks', 'digital infrastructure', 'machine learning', 'malicious connections', 'prevention', 'protection', 'zero-day network interruption attacks'], ['irreparable damage']]

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                         node    color  group
# 0      complexity and scale of cyber attacks  #5f57db      1
# 1                   cyber security landscape  #5f57db      1
# 2                  no defenses or safeguards  #5f57db      1
# 3                    unknown vulnerabilities  #5f57db      1
# 4   vulnerabilities in hardware and software  #5f57db      1
# 5                            zero-day attack  #5f57db      1
# 6                              cyber attacks  #db5f57      2
# 7                                 data leaks  #db5f57      2
# 8                     digital infrastructure  #db5f57      2
# 9                           machine learning  #db5f57      2
# 10                     malicious connections  #db5f57      2
# 11                                prevention  #db5f57      2
# 12                                protection  #db5f57      2
# 13     zero-day network interruption attacks  #db5f57      2
# 14                        irreparable damage  #57db5f      3

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
